# %%
# !pip install pandas

import pandas as pd
df = pd.read_csv("scripts/results/natural_insertion_raw.csv")
# See all columns
df.columns
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 26.9 MB/s eta 0:00:00m eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 33.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Index(['experiment', 'condition', 'concept', 'number', 'problem_idx',
#        'logprob', 'prob', 'number_verified', 'cot_length'],
#       dtype='str')

# %%
df[df["condition"] == "A1_math_then_probe"].head(20)
# Out:
#     experiment           condition     concept  number  problem_idx  \
# 110          A  A1_math_then_probe    elephant    55.0          0.0
# 111          A  A1_math_then_probe     dolphin    55.0          0.0
# 112          A  A1_math_then_probe        lion    55.0          0.0
# 113          A  A1_math_then_probe     giraffe    55.0          0.0
# 114          A  A1_math_then_probe       panda    55.0          0.0
# 115          A  A1_math_then_probe    kangaroo    55.0          0.0
# 116          A  A1_math_then_probe     penguin    55.0          0.0
# 117          A  A1_math_then_probe  chimpanzee    55.0          0.0
# 118          A  A1_math_then_probe       koala    55.0          0.0
# 119          A  A1_math_then_probe   orangutan    55.0          0.0
# 120          A  A1_math_then_probe    elephant    55.0          1.0
# 121          A  A1_math_then_probe     dolphin    55.0          1.0
# 122          A  A1_math_then_probe        lion    55.0          1.0
# ...

# %%
ENTANGLED = {"elephant":55, "dolphin":11, "lion":33, "giraffe":22, "panda":27,
               "kangaroo":20, "penguin":86, "chimpanzee":6, "koala":84, "orangutan":36}
matched = df[df.apply(lambda r: ENTANGLED.get(r["concept"]) == r["number"], axis=1)]
